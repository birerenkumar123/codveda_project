# %%
# !pip install sympy

# %%
import sympy as sp

# %%
x=sp.symbols('x')
f=x**2+3*x+2

# %%
sp.diff(f,x)
# Out:
# 2*x + 3

# %%
def singel_neurons(x):

# %%
yi=sp.symbols('yi')
w=sp.symbols('w')
x=sp.symbols('x')
f1=(yi-(w*x)**2)

# %%
f1
# Out:
# -w**2*x**2 + yi

# %%
sp.diff(f1,x)
# Out:
# -2*w**2*x

# %%
sp.diff(f1,yi)
# Out:
# 1

# %%
e=sp.symbols('e')
x=sp.symbols('x')
f=1/(1+e**(-x))
f
# Out:
# 1/(1 + e**(-x))

# %%
sp.diff(f,x)
# Out:
# log(e)/(e**x*(1 + e**(-x))**2)

# %%
sp.diff(f,yi)
# Out:
# 0

# %%
# Out:
# 1/(1 + e**(-x))

# %%
def neurn(input,wehight,bias):
    y=(input*wehight)+bias
    return y
neurn(2,33,1)
# Out:
# 67

# %%
def neuron(input,weght,bias):
    lst=0
    for i,w in zip(input,weght):
        lst+= i*w
    return lst+bias
neuron([1,2,3,4],[3,4,2,4],1)
# Out:
# 34

# %%
def neurons(input)

# %%
def neurons(input,weght):
    lst=0
    bias=len(weght)
    for i in input:
        for  j in range(len(weght)):
            for k in weght[j]:
                lst+= i*k+bias
    return lst
s=neurons([1,2,3,4],[[2,3],[3,4],[3,4],[5,7]])
s
# Out:
# 438

# %%
def sigmoid(x):
    e=np.exp(-x)
    d=1/1+(e)
    return d
y=sigmoid(s)
y
# Out:
# np.float64(1.0)

# %%
def neurons(input,weight):
    c=0
    for i in input:
        for j in range(len(weight)):
            for k in weight[j]:
                c+=i*k+len(weight)
    return c
p=neurons([1,2,3],[[1,2,3],[1,2,3]])

# %%
sigmoid(p)
# Out:
# np.float64(1.0)

# %%
neurons([1,2,3],[[2,3,3],[4,5,4],[3,4,3],[3,4,6]])
# Out:
# 408

# %%
sigmoid(neurons([1,2,3],[[2,3,3],[4,5,4],[3,4,3],[3,4,6]]))
# Out:
# np.float64(1.0)

# %%
def neurons()
