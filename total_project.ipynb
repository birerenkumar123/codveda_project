# %% [markdown]
# # task 1

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
data=sns.load_dataset('iris')
data.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
x=data['species'].values
x
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica'], dtype=object)

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
data.shape
# Out:
# (150, 5)

# %%
data.drop_duplicates(inplace=True)

# %%
data['species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 149, dtype: object

# %%
data['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     49
# Name: count, dtype: int64

# %%
def fun(x):
    if x=='setosa':
        return 0
    if x=='versicolor':
        return 1
    if x=='virginica':
        return 2

data['species']=data['species'].apply(fun)

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [149 rows x 5 columns]

# %%
numerical=data.drop(columns='species')
numerical
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [149 rows x 4 columns]

# %%
categoorical=data['species']
categoorical
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 149, dtype: int64

# %%
sns.barplot(categoorical.value_counts())#data is almost balance
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %% [markdown]
# # task2

# %%
data1=pd.read_csv('2) Stock Prices Data Set.csv')
data1.head()
# Out:
#   symbol        date      open      high       low     close    volume
# 0    AAL  2014-01-02   25.0700   25.8200   25.0600   25.3600   8998943
# 1   AAPL  2014-01-02   79.3828   79.5756   78.8601   79.0185  58791957
# 2    AAP  2014-01-02  110.3600  111.8800  109.2900  109.7400    542711
# 3   ABBV  2014-01-02   52.1200   52.3300   51.5200   51.9800   4569061
# 4    ABC  2014-01-02   70.1100   70.2300   69.4800   69.8900   1148391

# %%
data1.isnull().sum()
# Out:
# symbol     0
# date       0
# open      11
# high       8
# low        8
# close      0
# volume     0
# dtype: int64

# %%
data1['open'].isnull().sum()
# Out:
# 11

# %%
data1['open'].fillna(np.median(data),inplace=True)

# %%
data1['open'].isnull().sum()
# Out:
# 0

# %%
data1['high'].fillna(np.median(data1['high']),inplace=True)
# Out:
# C:\Users\BIREN KUMAR NAYAK\AppData\Local\Temp\ipykernel_20868\3832851928.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data1['high'].fillna(np.median(data1['high']),inplace=True)

# %%
data1['high'].isnull().sum()
# Out:
# 0

# %%
data1['low']
# Out:
# 0          25.0600
# 1          78.8601
# 2         109.2900
# 3          51.5200
# 4          69.4800
#             ...
# 497467     67.9200
# 497468     81.5900
# 497469    120.6200
# 497470     50.8100
# 497471     72.0400
# Name: low, Length: 497472, dtype: float64

# %%
data1['low']=data1['low'].fillna(np.median(data1['low']))

# %%
data1['low'].isnull().sum()
# Out:
# 8

# %%
data1
# Out:
#        symbol        date      open      high       low     close    volume
# 0         AAL  2014-01-02   25.0700   25.8200   25.0600   25.3600   8998943
# 1        AAPL  2014-01-02   79.3828   79.5756   78.8601   79.0185  58791957
# 2         AAP  2014-01-02  110.3600  111.8800  109.2900  109.7400    542711
# 3        ABBV  2014-01-02   52.1200   52.3300   51.5200   51.9800   4569061
# 4         ABC  2014-01-02   70.1100   70.2300   69.4800   69.8900   1148391
# ...       ...         ...       ...       ...       ...       ...       ...
# 497467    XYL  2017-12-29   68.5300   68.8000   67.9200   68.2000   1046677
# 497468    YUM  2017-12-29   82.6400   82.7100   81.5900   81.6100   1347613
# 497469    ZBH  2017-12-29  121.7500  121.9500  120.6200  120.6700   1023624
# 497470   ZION  2017-12-29   51.2800   51.5500   50.8100   50.8300   1261916
# 497471    ZTS  2017-12-29   72.5500   72.7600   72.0400   72.0400   1704122
#
# [497472 rows x 7 columns]

# %%
import datetime

# %%
data1['date']=pd.to_datetime(data1['date'])

# %%
data1.drop(columns='symbol',inplace=True)

# %%
sns.distplot(data1['open'])
# Out:
# C:\Users\BIREN KUMAR NAYAK\AppData\Local\Temp\ipykernel_20868\2210392908.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1['open'])
# <Axes: xlabel='open', ylabel='Density'>

# %%
sns.boxplot(data1['open'])
# Out:
# <Axes: ylabel='open'>

# %%
from scipy.stats import probplot
import matplotlib.pyplot as plt
probplot(data1['open'],dist='norm',plot=plt)
plt.show()

# %%
def emperial(x):
    lst=[]
    ll=np.mean(x)-3*np.std(x)
    ul=np.mean(x)+3*np.std(x)
    for i in x:
        if i>=ll and i<=ul:
            lst.append(i)
    return lst

sns.distplot(emperial(data1['open']))
# Out:
# C:\Users\BIREN KUMAR NAYAK\AppData\Local\Temp\ipykernel_20868\3043224793.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(emperial(data1['open']))
# <Axes: ylabel='Density'>

# %%
sns.boxplot(emperial(data1['open']))
# Out:
# <Axes: >

# %%
sns.distplot(data1['high'])
# Out:
# C:\Users\BIREN KUMAR NAYAK\AppData\Local\Temp\ipykernel_20868\4130210728.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1['high'])
# <Axes: xlabel='high', ylabel='Density'>

# %%
sns.boxplot(data1['high'])
# Out:
# <Axes: ylabel='high'>

# %%
def fun(x,t):
    lst=[]
    for i in x:
        if i>t:
            lst.append(i)
    return lst
sns.boxplot(fun(data1['high'],1250))
# Out:
# <Axes: >

# %%
sns.distplot(fun(data1['high'],1250))
# Out:
# C:\Users\BIREN KUMAR NAYAK\AppData\Local\Temp\ipykernel_20868\3270424456.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(fun(data1['high'],1250))
# <Axes: ylabel='Density'>

# %%
sns.distplot(data1['low'])
# Out:
# C:\Users\BIREN KUMAR NAYAK\AppData\Local\Temp\ipykernel_20868\2919107445.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1['low'])
# <Axes: xlabel='low', ylabel='Density'>

# %%
sns.boxplot(data1['low'])
# Out:
# <Axes: ylabel='low'>

# %%
def fun(x,t):
    lst=[]
    for i in x:
        if i>t:
            lst.append(i)
    return lst
sns.boxplot(fun(data1['low'],1250))
# Out:
# <Axes: >

# %%
sns.distplot(data1['volume'])
# Out:
# C:\Users\BIREN KUMAR NAYAK\AppData\Local\Temp\ipykernel_20868\1952587502.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data1['volume'])
# <Axes: xlabel='volume', ylabel='Density'>

# %%
sns.boxplot(data1['volume'])
# Out:
# <Axes: ylabel='volume'>

# %%
def fun(x,t):
    lst=[]
    for i in x:
        if i>t:
            lst.append(i)
    return lst
sns.boxplot(fun(data1['volume'],0.01))
# Out:
# <Axes: >

# %%
num=data1.drop(columns='date')

# %%
sns.heatmap(num.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(num.corr(method='spearman'))
# Out:
# <Axes: >

# %%
sns.heatmap(num.corr(method='kendall'))
# Out:
# <Axes: >

# %%
sns.scatterplot(data1,x='open',y='close',hue='volume')
# Out:
# <Axes: xlabel='open', ylabel='close'>
# C:\Users\BIREN KUMAR NAYAK\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# C:\Users\BIREN KUMAR NAYAK\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.scatterplot(data1,x='high',y='low',hue='volume')
# Out:
# <Axes: xlabel='high', ylabel='low'>
# C:\Users\BIREN KUMAR NAYAK\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)

# %%
sns.pairplot(data1)

# %%
#level2:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('2) Stock Prices Data Set.csv')

# %%
df.head()
# Out:
#   symbol        date      open      high       low     close    volume
# 0    AAL  2014-01-02   25.0700   25.8200   25.0600   25.3600   8998943
# 1   AAPL  2014-01-02   79.3828   79.5756   78.8601   79.0185  58791957
# 2    AAP  2014-01-02  110.3600  111.8800  109.2900  109.7400    542711
# 3   ABBV  2014-01-02   52.1200   52.3300   51.5200   51.9800   4569061
# 4    ABC  2014-01-02   70.1100   70.2300   69.4800   69.8900   1148391

# %%
df.isnull().sum()
# Out:
# symbol     0
# date       0
# open      11
# high       8
# low        8
# close      0
# volume     0
# dtype: int64

# %%
df['low'].fillna(np.mean(df['low']),inplace=True)
# Out:
# C:\Users\BIREN KUMAR NAYAK\AppData\Local\Temp\ipykernel_10392\3784221488.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['low'].fillna(np.mean(df['low']),inplace=True)

# %%
df['low'].isnull().sum()
# Out:
# 0

# %%
df['open'].fillna(np.mean(df['open']),inplace=True)
# Out:
# C:\Users\BIREN KUMAR NAYAK\AppData\Local\Temp\ipykernel_10392\2359601104.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['open'].fillna(np.mean(df['open']),inplace=True)

# %%
df['open'].isnull().sum()
# Out:
# 0

# %%
df['high'].fillna(np.mean(df['high']),inplace=True)
# Out:
# C:\Users\BIREN KUMAR NAYAK\AppData\Local\Temp\ipykernel_10392\3382411895.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['high'].fillna(np.mean(df['high']),inplace=True)

# %%
df['high'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# symbol    0
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %%
df['date']=pd.to_datetime(df['date'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
df.drop(columns='symbol',inplace=True)

# %%
x=df.drop(columns='volume')
x.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close'], dtype='object')

# %%
y=df['volume'].values
y
# Out:
# array([ 8998943, 58791957,   542711, ...,  1023624,  1261916,  1704122],
#       dtype=int64)

# %%
y = df['volume']                           
y
# Out:
# 0          8998943
# 1         58791957
# 2           542711
# 3          4569061
# 4          1148391
#             ...
# 497467     1046677
# 497468     1347613
# 497469     1023624
# 497470     1261916
# 497471     1704122
# Name: volume, Length: 497472, dtype: int64

# %%
X = df[['open', 'high', 'low', 'close']]   
X
# Out:
#             open      high       low     close
# 0        25.0700   25.8200   25.0600   25.3600
# 1        79.3828   79.5756   78.8601   79.0185
# 2       110.3600  111.8800  109.2900  109.7400
# 3        52.1200   52.3300   51.5200   51.9800
# 4        70.1100   70.2300   69.4800   69.8900
# ...          ...       ...       ...       ...
# 497467   68.5300   68.8000   67.9200   68.2000
# 497468   82.6400   82.7100   81.5900   81.6100
# 497469  121.7500  121.9500  120.6200  120.6700
# 497470   51.2800   51.5500   50.8100   50.8300
# 497471   72.5500   72.7600   72.0400   72.0400
#
# [497472 rows x 4 columns]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X,y,random_state=42,
                                           test_size=0.2)

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(xtest)

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
mean_squared_error(ytest,y_pred)
# Out:
# 68727140573942.06

# %%
r2_score(ytest,y_pred)
# Out:
# 0.027020227611588954

# %%
model.coef_
# Out:
# array([  13125.54476455,  382952.64346469, -410761.5257081 ,
#          -4116.12820408])

# %%
model.intercept_
# Out:
# 5237842.343711752

# %%
#time series anylisis
x['date']
# Out:
# 0        2014-01-02
# 1        2014-01-02
# 2        2014-01-02
# 3        2014-01-02
# 4        2014-01-02
#             ...
# 497467   2017-12-29
# 497468   2017-12-29
# 497469   2017-12-29
# 497470   2017-12-29
# 497471   2017-12-29
# Name: date, Length: 497472, dtype: datetime64[ns]

# %%
x['date']

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
sns.lineplot(df,x=x['date'],y=y)
# Out:
# <Axes: xlabel='date', ylabel='volume'>

# %% [markdown]
# ## k means_clustring

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

# Plot
plt.plot(range(1,11), wcss, marker='o')
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=42)  # example K=3
df['Cluster'] = kmeans.fit_predict(X_scaled)

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(
    x=df['open'],
    y=df['close'],
    hue=df['Cluster'],
    palette='viridis'
)

plt.title("K-Means Clustering")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(
    x=x['high'],
    y=x['low'],
    hue=df['Cluster'],
    palette='viridis'
)

plt.title("K-Means Clustering")
plt.show()

# %%
df
# Out:
#              date      open      high       low     close    volume  Cluster
# 0      2014-01-02   25.0700   25.8200   25.0600   25.3600   8998943        0
# 1      2014-01-02   79.3828   79.5756   78.8601   79.0185  58791957        0
# 2      2014-01-02  110.3600  111.8800  109.2900  109.7400    542711        0
# 3      2014-01-02   52.1200   52.3300   51.5200   51.9800   4569061        0
# 4      2014-01-02   70.1100   70.2300   69.4800   69.8900   1148391        0
# ...           ...       ...       ...       ...       ...       ...      ...
# 497467 2017-12-29   68.5300   68.8000   67.9200   68.2000   1046677        0
# 497468 2017-12-29   82.6400   82.7100   81.5900   81.6100   1347613        0
# 497469 2017-12-29  121.7500  121.9500  120.6200  120.6700   1023624        0
# 497470 2017-12-29   51.2800   51.5500   50.8100   50.8300   1261916        0
# 497471 2017-12-29   72.5500   72.7600   72.0400   72.0400   1704122        0
#
# [497472 rows x 7 columns]

# %%
# prediction anylis useing clasiificatiron

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('senti.csv')

# %%
df.drop(columns=['Unnamed: 0.1','Unnamed: 0'],inplace=True)

# %%
df['text_new']=df['Text']+''+df['User']+''+df['Platform']+''+df['Country']+''+df['Hashtags']

# %%
df.drop(columns=['Text','User','Platform','Hashtags','Country','Retweets','Timestamp'],inplace=True)

# %%
df['text_new']
# Out:
# 0       Enjoying a beautiful day at the park!        ...
# 1       Traffic was terrible this morning.           ...
# 2       Just finished an amazing workout! 💪          ...
# 3       Excited about the upcoming weekend getaway!  ...
# 4       Trying out a new recipe for dinner tonight.  ...
#                              ...
# 727    Collaborating on a science project that receiv...
# 728    Attending a surprise birthday party organized ...
# 729    Successfully fundraising for a school charity ...
# 730    Participating in a multicultural festival, cel...
# 731    Organizing a virtual talent show during challe...
# Name: text_new, Length: 732, dtype: object

# %%
df.isnull().sum()
# Out:
# Sentiment    0
# Likes        0
# Year         0
# Month        0
# Day          0
# Hour         0
# text_new     0
# dtype: int64

# %%
x=df.drop(columns='Sentiment')
y=df['Sentiment']

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)
xtrain_l=xtrain.astype("str")
xtest_l=xtest.astype("str")

# %%
#we use the multinomial naivebeys which help to do many thing
xtest_l
# Out:
#     Likes  Year Month Day Hour  \
# 604  45.0  2023     6  13   14
# 33   50.0  2023     1  26    9
# 300  36.0  2022     5  12    2
# 457  45.0  2019     4  18   11
# 634  70.0  2023     7  13   20
# ..    ...   ...   ...  ..  ...
# 70   30.0  2023     2  18    9
# 192  15.0  2018     8   5   16
# 328  40.0  2021     1  15   22
# 165  20.0  2019    11  18   21
# 135  50.0  2021     3   2    9
#
#                                               text_new
# 604  Exploring the world of digital art. It's never...
# 33    Feeling inspired after attending a workshop. ...
# 300   Eyes wide open in the night, fearful shadows ...
# 457  A soul weathered by the storm of heartbreak, s...
# 634  Attended a wine tasting event, savoring the ri...
# ..                                                 ...
# 70    Finding calmness in the midst of a busy day. ...
# 192   Jealousy poisons my thoughts, resentment brew...
# 328   Envious eyes locked on the treasure chest of ...
# 165   Loneliness creeps in as the night grows colde...
# 135   Elation after achieving a personal goal.     ...
#
# [147 rows x 6 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer=TfidfVectorizer(stop_words="english")
xtrain_tfidf=vectorizer.fit_transform(xtrain_l)
xtest_tfidf=vectorizer.transform(xtest_l)

# %%
from sklearn.naive_bayes import MultinomialNB
model=MultinomialNB()

# %%
from sklearn.model_selection import GridSearchCV

# %%
params_grid={
    "alpha":[0.01,0.1,1.0,2.0]
}

# %%
grid=GridSearchCV(
    estimator=model,
    param_grid=params_grid,
    cv=5,
    scoring="accuracy")

# %%
grid.fit(xtrain_tfidf,ytrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 grid.fit(xtrain_tfidf,ytrain)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:928, in BaseSearchCV.fit(self, X, y, **params)
#     925 estimator = self.estimator
#     926 scorers, refit_metric = self._get_scorers()
# --> 928 X, y = indexable(X, y)
#     929 params = _check_method_params(X, params=params)
#     931 routed_params = self._get_routed_params_for_fit(params)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:532, in indexable(*iterables)
#     502 """Make arrays indexable for cross-validation.
#     503
#     504 Checks consistent length, passes through None, and ensures that everything
#    (...)
#     528 [[1, 2, 3], array([2, 3, 4]), None, <...Sparse...dtype 'int64'...shape (3, 1)>]
#     529 """
#     531 result = [_make_indexable(X) for X in iterables]
# --> 532 check_consistent_length(*result)
#     533 return result
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:475, in check_consistent_length(*arrays)
#     473 uniques = np.unique(lengths)
#     474 if len(uniques) > 1:
# --> 475     raise ValueError(
#     476         "Found input variables with inconsistent numbers of samples: %r"
#     477         % [int(l) for l in lengths]
#     478     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [6, 585]
